# %%
import pandas as pd, re
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
from datetime import datetime, timedelta
import datetime as dt
import calendar
import matplotlib.dates as mdates
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score, mean_absolute_error
import math
import holidays
from operator import itemgetter

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(absolute_percentage_error(y_true, y_pred))

def absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.abs((y_true - y_pred) / y_true) * 100

# %%
df = pd.read_csv('demandForecastingData.csv', parse_dates=['Date'])

# %%
def add_datepart(df, fldname, drop=True, time=False):
    """add_datepart converts a column of df from a datetime64 to many columns containing
    the information from the date. This applies changes inplace.
    Parameters:
    -----------
    df: A pandas data frame. df gain several new columns.
    fldname: A string that is the name of the date column you wish to expand.
        If it is not a datetime64 series, it will be converted to one with pd.to_datetime.
    drop: If true then the original date column will be removed.
    time: If true time features: Hour, Minute, Second will be added.
    Examples:
    ---------
    >>> df = pd.DataFrame({ 'A' : pd.to_datetime(['3/11/2000', '3/12/2000', '3/13/2000'], infer_datetime_format=False) })
    >>> df
        A
    0   2000-03-11
    1   2000-03-12
    2   2000-03-13
    >>> add_datepart(df, 'A')
    >>> df
        AYear AMonth AWeek ADay ADayofweek ADayofyear AIs_month_end AIs_month_start AIs_quarter_end AIs_quarter_start AIs_year_end AIs_year_start AElapsed
    0   2000  3      10    11   5          71         False         False           False           False             False        False          952732800
    1   2000  3      10    12   6          72         False         False           False           False             False        False          952819200
    2   2000  3      11    13   0          73         False         False           False           False             False        False          952905600
    """
    fld = df[fldname]
    fld_dtype = fld.dtype
    if isinstance(fld_dtype, pd.core.dtypes.dtypes.DatetimeTZDtype):
        fld_dtype = np.datetime64

    if not np.issubdtype(fld_dtype, np.datetime64):
        df[fldname] = fld = pd.to_datetime(fld, infer_datetime_format=True)
    targ_pre = re.sub('[Dd]ate$', '', fldname)
    attr = ['Year', 'Month', 'Week', 'Quarter', 'Hour', 'Minute', 'Day', 'Dayofweek', 'Dayofyear']
    for n in attr: df[targ_pre + n] = getattr(fld.dt, n.lower())
    if drop: df.drop(fldname, axis=1, inplace=True)

# %%
add_datepart(df, 'Date', drop=False)

# %%
df.corr().sort_values('Load')
# Out:
#                                              Load  Temperature  \
# Daily cycle (sine wave)                 -0.590643    -0.204951
# Temperature-48hrs                       -0.510385     0.633506
# Temperature-12hrs                       -0.508043     0.708463
# Daily cycle (cosine wave)               -0.472573    -0.175561
# Temperature over 18hrs                  -0.376075     0.875345
# Temperature over 72hrs                  -0.362411     0.858733
# Temperature over 96hrs                  -0.345607     0.862747
# Temperature over 48hrs                  -0.339241     0.874140
# Temperature over 24hrs                  -0.338024     0.890790
# Temperature over 12hrs                  -0.319549     0.897231
# Temperature over 36hrs                  -0.313320     0.894961
# Temperature-36hrs                       -0.298608     0.737224
# Temperature-6hrs                        -0.297908     0.839822
# Temperature-18hrs                       -0.293672     0.775664
# Temperature-72hrs                       -0.293379     0.711341
# Temperature over 6hrs                   -0.195296     0.958431
# Year                                    -0.190812     0.027103
# Temperature                             -0.139964     1.000000
# Humidity                                -0.137788    -0.395745
# Temperature-24hrs                       -0.137125     0.859649
# Temperature-96hrs                       -0.136057     0.804058
# Dayofweek                               -0.118923    -0.008758
# Binary indicator sunny day              -0.115316     0.193727
# Holiday_Alternate                       -0.060885    -0.059644
# Cloud height                            -0.051599    -0.039393
# Visibility                              -0.048619     0.194273
# Day                                     -0.026564     0.070265
# Dayofyear                               -0.016926     0.117377
# Quarter                                 -0.016224     0.114665
# Month                                   -0.015543     0.113100
# Week                                    -0.014569     0.111928
# Minute                                  -0.002647     0.000000
# Wind direction                           0.026133     0.071644
# Weekday                                  0.028622     0.000523
# Yearly cycle (sine wave)                 0.046308    -0.297988
# Binary indicator windy day               0.070030    -0.063171
# Wind speed^3                             0.105158     0.009477
# Sun duration*potential solar irradiance  0.106340     0.322979
# Wind speed^2                             0.120743     0.043631
# Wind speed                               0.127820     0.100696
# Sun duration                             0.159171     0.278793
# Potential solar irradiance               0.218554     0.437005
# Yearly cycle (cosine wave)               0.363234    -0.692006
# Hour                                     0.561594     0.147869
# Load                                     1.000000    -0.139964
#
#                                          Temperature-6hrs  Temperature-12hrs  \
# Daily cycle (sine wave)                         -0.177409           0.207870
# Temperature-48hrs                                0.737248           0.859589
# Temperature-12hrs                                0.839838           1.000000
# Daily cycle (cosine wave)                        0.206031           0.176474
# Temperature over 18hrs                           0.947387           0.943455
# Temperature over 72hrs                           0.901539           0.913749
# Temperature over 96hrs                           0.885214           0.898773
# Temperature over 48hrs                           0.920029           0.908770
# Temperature over 24hrs                           0.918139           0.925738
# Temperature over 12hrs                           0.982143           0.884492
# Temperature over 36hrs                           0.919396           0.903513
# Temperature-36hrs                                0.859642           0.775655
# Temperature-6hrs                                 1.000000           0.839838
# Temperature-18hrs                                0.708479           0.839829
# Temperature-72hrs                                0.633513           0.737182
# Temperature over 6hrs                            0.944848           0.769199
# Year                                             0.026878           0.026632
# Temperature                                      0.839822           0.708463
# Humidity                                        -0.182826          -0.009464
# Temperature-24hrs                                0.775699           0.708537
# Temperature-96hrs                                0.711445           0.633666
# Dayofweek                                       -0.008325          -0.008021
# Binary indicator sunny day                       0.187158           0.172123
# Holiday_Alternate                               -0.060563          -0.062364
# Cloud height                                     0.035169           0.017207
# Visibility                                       0.148804           0.076573
# Day                                              0.070608           0.070933
# Dayofyear                                        0.119875           0.122089
# Quarter                                          0.117683           0.120494
# Month                                            0.115572           0.117754
# Week                                             0.115329           0.118234
# Minute                                           0.000000           0.000000
# Wind direction                                   0.036472           0.019275
# Weekday                                          0.004408           0.007948
# Yearly cycle (sine wave)                        -0.301036          -0.304535
# Binary indicator windy day                      -0.064972          -0.068191
# Wind speed^3                                    -0.047554          -0.087927
# Sun duration*potential solar irradiance          0.006914           0.018027
# Wind speed^2                                    -0.035545          -0.087250
# Wind speed                                      -0.003367          -0.070004
# Sun duration                                    -0.003634          -0.042187
# Potential solar irradiance                       0.073026           0.097626
# Yearly cycle (cosine wave)                      -0.690780          -0.689740
# Hour                                             0.149991          -0.182217
# Load                                            -0.297908          -0.508043
#
#                                          Temperature-18hrs  Temperature-24hrs  \
# Daily cycle (sine wave)                           0.173279          -0.204824
# Temperature-48hrs                                 0.775650           0.708640
# Temperature-12hrs                                 0.839829           0.708537
# Daily cycle (cosine wave)                        -0.206820          -0.175483
# Temperature over 18hrs                            0.868639           0.835228
# Temperature over 72hrs                            0.900518           0.901705
# Temperature over 96hrs                            0.906427           0.909038
# Temperature over 48hrs                            0.891383           0.911145
# Temperature over 24hrs                            0.916670           0.887671
# Temperature over 12hrs                            0.782126           0.823901
# Temperature over 36hrs                            0.904727           0.919802
# Temperature-36hrs                                 0.708532           0.839915
# Temperature-6hrs                                  0.708479           0.775699
# Temperature-18hrs                                 1.000000           0.839863
# Temperature-72hrs                                 0.859573           0.775709
# Temperature over 6hrs                             0.746486           0.850078
# Year                                              0.026453           0.026433
# Temperature                                       0.775664           0.859649
# Humidity                                         -0.157669          -0.348017
# Temperature-24hrs                                 0.839863           1.000000
# Temperature-96hrs                                 0.737273           0.859620
# Dayofweek                                        -0.006640          -0.004164
# Binary indicator sunny day                        0.171804           0.183442
# Holiday_Alternate                                -0.063543          -0.063972
# Cloud height                                     -0.020149           0.024894
# Visibility                                        0.105630           0.185233
# Day                                               0.070918           0.070672
# Dayofyear                                         0.122123           0.121581
# Quarter                                           0.121536           0.121794
# Month                                             0.117775           0.117239
# Week                                              0.119614           0.120252
# Minute                                           -0.000012           0.000000
# Wind direction                                    0.070455           0.109263
# Weekday                                           0.010590           0.013441
# Yearly cycle (sine wave)                         -0.307546          -0.309835
# Binary indicator windy day                       -0.082965          -0.097478
# Wind speed^3                                     -0.077213          -0.072399
# Sun duration*potential solar irradiance           0.255324           0.289677
# Wind speed^2                                     -0.064726          -0.050902
# Wind speed                                       -0.031256          -0.002886
# Sun duration                                      0.168072           0.254693
# Potential solar irradiance                        0.432055           0.433911
# Yearly cycle (cosine wave)                       -0.688371          -0.686828
# Hour                                             -0.113962           0.147771
# Load                                             -0.293672          -0.137125
#
#                                          Temperature-36hrs  Temperature-48hrs  \
# Daily cycle (sine wave)                          -0.177399           0.207708
# Temperature-48hrs                                 0.839905           1.000000
# Temperature-12hrs                                 0.775655           0.859589
# Daily cycle (cosine wave)                         0.205895           0.176459
# Temperature over 18hrs                            0.853532           0.830632
# Temperature over 72hrs                            0.914198           0.898824
# Temperature over 96hrs                            0.906068           0.897949
# Temperature over 48hrs                            0.918503           0.868575
# Temperature over 24hrs                            0.854493           0.831008
# Temperature over 12hrs                            0.862387           0.775510
# Temperature over 36hrs                            0.890236           0.833534
# Temperature-36hrs                                 1.000000           0.839905
# Temperature-6hrs                                  0.859642           0.737248
# Temperature-18hrs                                 0.708532           0.775650
# Temperature-72hrs                                 0.708617           0.839874
# Temperature over 6hrs                             0.821147           0.681753
# Year                                              0.026212           0.025851
# Temperature                                       0.737224           0.633506
# Humidity                                         -0.187850          -0.029641
# Temperature-24hrs                                 0.839915           0.708640
# Temperature-96hrs                                 0.775851           0.708859
# Dayofweek                                        -0.000411           0.003467
# Binary indicator sunny day                        0.183552           0.175608
# Holiday_Alternate                                -0.065138          -0.067289
# Cloud height                                      0.080897           0.047443
# Visibility                                        0.161623           0.096285
# Day                                               0.071504           0.072359
# Dayofyear                                         0.122737           0.125443
# Quarter                                           0.123092           0.125407
# Month                                             0.118317           0.120950
# Week                                              0.121544           0.124160
# Minute                                            0.000000           0.000000
# Wind direction                                    0.064854           0.037392
# Weekday                                           0.013850           0.015112
# Yearly cycle (sine wave)                         -0.312888          -0.316425
# Binary indicator windy day                       -0.105043          -0.108823
# Wind speed^3                                     -0.117894          -0.130807
# Sun duration*potential solar irradiance           0.047891           0.045179
# Wind speed^2                                     -0.115346          -0.138129
# Wind speed                                       -0.087036          -0.124325
# Sun duration                                      0.044942          -0.005533
# Potential solar irradiance                        0.070085           0.094621
# Yearly cycle (cosine wave)                       -0.685553          -0.684492
# Hour                                              0.150009          -0.182097
# Load                                             -0.298608          -0.510385
#
#                                          Temperature-72hrs  Temperature-96hrs  \
# Daily cycle (sine wave)                           0.173220          -0.204635
# Temperature-48hrs                                 0.839874           0.708859
# Temperature-12hrs                                 0.737182           0.633666
# Daily cycle (cosine wave)                        -0.206704          -0.175386
# Temperature over 18hrs                            0.769356           0.758121
# Temperature over 72hrs                            0.854917           0.830779
# Temperature over 96hrs                            0.883694           0.860601
# Temperature over 48hrs                            0.820139           0.823805
# Temperature over 24hrs                            0.812212           0.795928
# Temperature over 12hrs                            0.700888           0.756305
# Temperature over 36hrs                            0.813528           0.822749
# Temperature-36hrs                                 0.708617           0.775851
# Temperature-6hrs                                  0.633513           0.711445
# Temperature-18hrs                                 0.859573           0.737273
# Temperature-72hrs                                 1.000000           0.840008
# Temperature over 6hrs                             0.676555           0.788934
# Year                                              0.025542           0.025484
# Temperature                                       0.711341           0.804058
# Humidity                                         -0.166060          -0.344514
# Temperature-24hrs                                 0.775709           0.859620
# Temperature-96hrs                                 0.840008           1.000000
# Dayofweek                                         0.005129           0.005681
# Binary indicator sunny day                        0.172568           0.174330
# Holiday_Alternate                                -0.068362          -0.068988
# Cloud height                                      0.001850           0.035661
# Visibility                                        0.121398           0.197008
# Day                                               0.073215           0.074053
# Dayofyear                                         0.127640           0.128874
# Quarter                                           0.127042           0.128005
# Month                                             0.123062           0.124208
# Week                                              0.126024           0.126970
# Minute                                            0.000000           0.000000
# Wind direction                                    0.076651           0.110378
# Weekday                                           0.014025           0.012908
# Yearly cycle (sine wave)                         -0.319442          -0.321701
# Binary indicator windy day                       -0.109604          -0.111106
# Wind speed^3                                     -0.098593          -0.079536
# Sun duration*potential solar irradiance           0.256896           0.282880
# Wind speed^2                                     -0.093717          -0.064884
# Wind speed                                       -0.066369          -0.024909
# Sun duration                                      0.176692           0.248832
# Potential solar irradiance                        0.428939           0.430727
# Yearly cycle (cosine wave)                       -0.683083          -0.681531
# Hour                                             -0.113901           0.147596
# Load                                             -0.293379          -0.136057
#
#                                            ...      Holiday_Alternate  \
# Daily cycle (sine wave)                    ...              -0.000001
# Temperature-48hrs                          ...              -0.067289
# Temperature-12hrs                          ...              -0.062364
# Daily cycle (cosine wave)                  ...              -0.000006
# Temperature over 18hrs                     ...              -0.066110
# Temperature over 72hrs                     ...              -0.070473
# Temperature over 96hrs                     ...              -0.071528
# Temperature over 48hrs                     ...              -0.069238
# Temperature over 24hrs                     ...              -0.067530
# Temperature over 12hrs                     ...              -0.063679
# Temperature over 36hrs                     ...              -0.068270
# Temperature-36hrs                          ...              -0.065138
# Temperature-6hrs                           ...              -0.060563
# Temperature-18hrs                          ...              -0.063543
# Temperature-72hrs                          ...              -0.068362
# Temperature over 6hrs                      ...              -0.061153
# Year                                       ...              -0.012587
# Temperature                                ...              -0.059644
# Humidity                                   ...              -0.001893
# Temperature-24hrs                          ...              -0.063972
# Temperature-96hrs                          ...              -0.068988
# Dayofweek                                  ...              -0.027969
# Binary indicator sunny day                 ...               0.010138
# Holiday_Alternate                          ...               1.000000
# Cloud height                               ...               0.012549
# Visibility                                 ...               0.007380
# Day                                        ...               0.037443
# Dayofyear                                  ...               0.099947
# Quarter                                    ...               0.083966
# Month                                      ...               0.097364
# Week                                       ...               0.095267
# Minute                                     ...               0.000000
# Wind direction                             ...              -0.015930
# Weekday                                    ...              -0.022953
# Yearly cycle (sine wave)                   ...               0.089964
# Binary indicator windy day                 ...               0.043736
# Wind speed^3                               ...               0.032769
# Sun duration*potential solar irradiance    ...              -0.005061
# Wind speed^2                               ...               0.030180
# Wind speed                                 ...               0.021757
# Sun duration                               ...              -0.001484
# Potential solar irradiance                 ...              -0.021761
# Yearly cycle (cosine wave)                 ...               0.062290
# Hour                                       ...               0.000007
# Load                                       ...              -0.060885
#
#                                              Year     Month      Week  \
# Daily cycle (sine wave)                  0.000006 -0.000006 -0.000006
# Temperature-48hrs                        0.025851  0.120950  0.124160
# Temperature-12hrs                        0.026632  0.117754  0.118234
# Daily cycle (cosine wave)                0.000034 -0.000031 -0.000033
# Temperature over 18hrs                   0.028798  0.125522  0.125958
# Temperature over 72hrs                   0.029154  0.130965  0.133123
# Temperature over 96hrs                   0.029194  0.132521  0.134811
# Temperature over 48hrs                   0.029096  0.129320  0.131249
# Temperature over 24hrs                   0.029053  0.127405  0.128537
# Temperature over 12hrs                   0.028217  0.121472  0.121362
# Temperature over 36hrs                   0.029081  0.128186  0.129790
# Temperature-36hrs                        0.026212  0.118317  0.121544
# Temperature-6hrs                         0.026878  0.115572  0.115329
# Temperature-18hrs                        0.026453  0.117775  0.119614
# Temperature-72hrs                        0.025542  0.123062  0.126024
# Temperature over 6hrs                    0.027522  0.116456  0.115779
# Year                                     1.000000 -0.053266 -0.051499
# Temperature                              0.027103  0.113100  0.111928
# Humidity                                -0.027824  0.086130  0.088502
# Temperature-24hrs                        0.026433  0.117239  0.120252
# Temperature-96hrs                        0.025484  0.124208  0.126970
# Dayofweek                               -0.001078 -0.000592  0.001103
# Binary indicator sunny day               0.039626 -0.042857 -0.043909
# Holiday_Alternate                       -0.012587  0.097364  0.095267
# Cloud height                            -0.050494 -0.004120 -0.004370
# Visibility                               0.224884 -0.011383 -0.008817
# Day                                     -0.014784 -0.010443  0.044850
# Dayofyear                               -0.054206  0.996430  0.969041
# Quarter                                 -0.054892  0.971366  0.943919
# Month                                   -0.053266  1.000000  0.967781
# Week                                    -0.051499  0.967781  1.000000
# Minute                                   0.000000  0.000000  0.000000
# Wind direction                           0.014030  0.019023  0.024494
# Weekday                                  0.000567 -0.000253 -0.002566
# Yearly cycle (sine wave)                 0.091475 -0.475259 -0.480188
# Binary indicator windy day               0.013455 -0.014162 -0.015732
# Wind speed^3                             0.016260 -0.016829 -0.013445
# Sun duration*potential solar irradiance  0.013769 -0.031247 -0.030943
# Wind speed^2                             0.026596 -0.018455 -0.016263
# Wind speed                               0.041698 -0.020895 -0.020035
# Sun duration                             0.009845 -0.025268 -0.024790
# Potential solar irradiance               0.006579 -0.051036 -0.052690
# Yearly cycle (cosine wave)               0.001627  0.029704  0.032960
# Hour                                    -0.000038  0.000035  0.000037
# Load                                    -0.190812 -0.015543 -0.014569
#
#                                           Quarter          Hour    Minute  \
# Daily cycle (sine wave)                 -0.000005 -8.142628e-01 -0.002817
# Temperature-48hrs                        0.125407 -1.820972e-01  0.000000
# Temperature-12hrs                        0.120494 -1.822168e-01  0.000000
# Daily cycle (cosine wave)               -0.000026 -2.842907e-02 -0.000099
# Temperature over 18hrs                   0.128201 -5.338307e-03  0.000013
# Temperature over 72hrs                   0.134971 -2.130775e-03  0.000015
# Temperature over 96hrs                   0.136586  3.902977e-04  0.000014
# Temperature over 48hrs                   0.133187  3.374581e-02  0.000014
# Temperature over 24hrs                   0.130587  3.976110e-04  0.000012
# Temperature over 12hrs                   0.123705  9.584024e-02  0.000012
# Temperature over 36hrs                   0.131781  4.094583e-02  0.000013
# Temperature-36hrs                        0.123092  1.500092e-01  0.000000
# Temperature-6hrs                         0.117683  1.499914e-01  0.000000
# Temperature-18hrs                        0.121536 -1.139616e-01 -0.000012
# Temperature-72hrs                        0.127042 -1.139010e-01  0.000000
# Temperature over 6hrs                    0.118251  1.887830e-01  0.000010
# Year                                    -0.054892 -3.841059e-05  0.000000
# Temperature                              0.114665  1.478686e-01  0.000000
# Humidity                                 0.089786 -2.532077e-01  0.000000
# Temperature-24hrs                        0.121794  1.477706e-01  0.000000
# Temperature-96hrs                        0.128005  1.475959e-01  0.000000
# Dayofweek                               -0.000027 -3.346049e-05  0.000000
# Binary indicator sunny day              -0.041064  7.203242e-06  0.000000
# Holiday_Alternate                        0.083966  6.731820e-06  0.000000
# Cloud height                            -0.001317  5.123678e-02  0.000000
# Visibility                              -0.009917  1.105593e-01  0.000000
# Day                                     -0.009419  2.176342e-05  0.000000
# Dayofyear                                0.968055  3.663370e-05  0.000000
# Quarter                                  1.000000  2.942628e-05  0.000000
# Month                                    0.971366  3.504750e-05  0.000000
# Week                                     0.943919  3.727261e-05  0.000000
# Minute                                   0.000000  0.000000e+00  1.000000
# Wind direction                           0.018359  5.116371e-02  0.000000
# Weekday                                 -0.000747  3.347174e-05  0.000000
# Yearly cycle (sine wave)                -0.490133  5.087549e-07  0.000000
# Binary indicator windy day              -0.018286  6.731820e-06  0.000000
# Wind speed^3                            -0.021536  2.528866e-02  0.000000
# Sun duration*potential solar irradiance -0.029708  3.842114e-02 -0.006935
# Wind speed^2                            -0.023296  3.596996e-02  0.000000
# Wind speed                              -0.025613  5.207412e-02  0.000000
# Sun duration                            -0.023259  1.099717e-01  0.000000
# Potential solar irradiance              -0.053839  2.881231e-02  0.000644
# Yearly cycle (cosine wave)               0.033014  3.151306e-05  0.000000
# Hour                                     0.000029  1.000000e+00  0.000000
# Load                                    -0.016224  5.615943e-01 -0.002647
#
#                                               Day  Dayofweek  Dayofyear
# Daily cycle (sine wave)                 -0.000003   0.000005  -0.000006
# Temperature-48hrs                        0.072359   0.003467   0.125443
# Temperature-12hrs                        0.070933  -0.008021   0.122089
# Daily cycle (cosine wave)               -0.000019   0.000029  -0.000032
# Temperature over 18hrs                   0.076304  -0.008766   0.130178
# Temperature over 72hrs                   0.079009  -0.004322   0.135819
# Temperature over 96hrs                   0.079789  -0.003084   0.137436
# Temperature over 48hrs                   0.078194  -0.005777   0.134114
# Temperature over 24hrs                   0.077267  -0.008161   0.132126
# Temperature over 12hrs                   0.074267  -0.008897   0.125998
# Temperature over 36hrs                   0.077637  -0.007173   0.132936
# Temperature-36hrs                        0.071504  -0.000411   0.122737
# Temperature-6hrs                         0.070608  -0.008325   0.119875
# Temperature-18hrs                        0.070918  -0.006640   0.122123
# Temperature-72hrs                        0.073215   0.005129   0.127640
# Temperature over 6hrs                    0.071810  -0.008795   0.120829
# Year                                    -0.014784  -0.001078  -0.054206
# Temperature                              0.070265  -0.008758   0.117377
# Humidity                                -0.013489  -0.004533   0.085787
# Temperature-24hrs                        0.070672  -0.004164   0.121581
# Temperature-96hrs                        0.074053   0.005681   0.128874
# Dayofweek                               -0.000165   1.000000  -0.000607
# Binary indicator sunny day               0.017624  -0.003313  -0.042304
# Holiday_Alternate                        0.037443  -0.027969   0.099947
# Cloud height                             0.013084  -0.001215  -0.003330
# Visibility                               0.028187   0.011861  -0.009213
# Day                                      1.000000  -0.000165   0.073707
# Dayofyear                                0.073707  -0.000607   1.000000
# Quarter                                 -0.009419  -0.000027   0.968055
# Month                                   -0.010443  -0.000592   0.996430
# Week                                     0.044850   0.001103   0.969041
# Minute                                   0.000000   0.000000   0.000000
# Wind direction                           0.028921   0.013735   0.021252
# Weekday                                  0.001177   0.153818  -0.000141
# Yearly cycle (sine wave)                -0.130781  -0.001238  -0.485921
# Binary indicator windy day              -0.031792  -0.004084  -0.016553
# Wind speed^3                            -0.014253   0.005221  -0.017791
# Sun duration*potential solar irradiance  0.014779   0.007529  -0.030679
# Wind speed^2                            -0.010741   0.008053  -0.019072
# Wind speed                              -0.004629   0.009438  -0.020993
# Sun duration                             0.011604   0.006083  -0.024805
# Potential solar irradiance               0.005631  -0.001209  -0.051467
# Yearly cycle (cosine wave)              -0.038228   0.002689   0.028781
# Hour                                     0.000022  -0.000033   0.000037
# Load                                    -0.026564  -0.118923  -0.016926
#
# [45 rows x 45 columns]

# %% [markdown]
# # Temperature Only Regression Model

# %%
metrics_df = pd.DataFrame(columns=['Training Year', 'Test Year', 'Coefficient', 'Intercept', 'MAPE'])
for train_year in range(2012, 2018):
    df_train_year = df[df.Year == train_year]
    for test_year in range(2012, 2018):
            df_test_year = df[df.Year == test_year]
            y_train = df_train_year['Load']#
            x_train = df_train_year[['Temperature']]#
            y_test = df_test_year['Load']
            x_test = df_test_year[['Temperature']]
            regressor = LinearRegression()#
            result = regressor.fit(x_train, y_train)#
            y_pred = regressor.predict(x_test)
            metrics_df.loc[len(metrics_df)]=[train_year,test_year,regressor.coef_,regressor.intercept_, mean_absolute_percentage_error(y_test, y_pred)]

# %%
metrics_df[metrics_df['Training Year'] == metrics_df['Test Year']-1].sort_values('MAPE', ascending=True)
# Out:
#    Training Year Test Year            Coefficient    Intercept       MAPE
# 15          2014      2015  [-5.1466995552332975]  1036.844585  23.543209
# 22          2015      2016   [-4.686624636354221]  1025.998007  24.136713
# 8           2013      2014   [-6.044749583313259]  1060.726773  24.144735
# 1           2012      2013  [-1.7848585537102735]  1035.630226  24.265233
# 29          2016      2017   [-5.738832999247977]  1014.647528  25.463496

# %%
metrics_df[metrics_df['Training Year'] == metrics_df['Test Year']-1].MAPE.mean()
# Out:
# 24.310677228977703

# %%
metrics_df_transpose = metrics_df[['Training Year', 'Test Year', 'MAPE']].copy()
metrics_df_transpose = metrics_df_transpose.pivot(index='Training Year', columns='Test Year')
metrics_df_transpose.to_csv('temperature_only_year_by_year.csv')

# %% [markdown]
# # Load Last Week Regression Model

# %%
def displaced_by_week(df, year):
    end_date = datetime(year+1, 1, 1)
    start_date = datetime(year, 1, 1)
    start_date_displaced_week = start_date - timedelta(minutes=10080)
    end_date_displaced_week = end_date - timedelta(minutes=10080)
    df_displaced = df[(df.Date >= start_date_displaced_week) & (df.Date < end_date_displaced_week)].reset_index(drop=True)
    return df_displaced

# %%
metrics_df = pd.DataFrame(columns=['Training Year', 'Test Year', 'SDLW Coefficient', 'Intercept', 'MAPE'])
for train_year in range(2012, 2018):
    df_train_year = df[df.Year == train_year].reset_index()
    df_same_week_displaced_train = displaced_by_week(df, train_year)
    df_train_year['Load Last Week'] = df_same_week_displaced_train['Load']

    for test_year in range(2012, 2018):
            df_test_year = df[df.Year == test_year].reset_index()
            df_same_week_displaced_test = displaced_by_week(df, test_year)
            df_test_year['Load Last Week'] = df_same_week_displaced_test['Load']
            
            y_train = df_train_year['Load']
            x_train = df_train_year[['Load Last Week']]
            y_test = df_test_year['Load']
            x_test = df_test_year[['Load Last Week']]
            
            regressor = LinearRegression()
            result = regressor.fit(x_train, y_train)
            y_pred = regressor.predict(x_test)
            metrics_df.loc[len(metrics_df)]=[train_year,test_year,regressor.coef_[0],regressor.intercept_, mean_absolute_percentage_error(y_test, y_pred)]

# %%
metrics_df[metrics_df['Training Year'] == metrics_df['Test Year']-1].sort_values('MAPE', ascending=True)
# Out:
#     Training Year  Test Year  SDLW Coefficient  Intercept      MAPE
# 8          2013.0     2014.0          0.969976  30.314334  3.628210
# 1          2012.0     2013.0          0.965625  33.785701  3.833675
# 15         2014.0     2015.0          0.973606  25.822810  4.073615
# 22         2015.0     2016.0          0.963478  35.327079  4.568105
# 29         2016.0     2017.0          0.959657  37.672387  5.838007

# %%
metrics_df[metrics_df['Training Year'] == metrics_df['Test Year']-1].MAPE.mean()
# Out:
# 4.388322281975519

# %%
metrics_df_transpose = metrics_df[['Training Year', 'Test Year', 'MAPE']].copy()
metrics_df_transpose = metrics_df_transpose.pivot(index='Training Year', columns='Test Year')
metrics_df_transpose.to_csv('load_last_week_year_by_year.csv')

# %% [markdown]
# # SDLW Temperature Corrected Model

# %%
metrics_df = pd.DataFrame(columns=['Training Year', 'Test Year', 'Temp Difference Coefficient', 'Intercept', 'MAPE'])
for train_year in range(2012, 2018):
    df_train_year = df[df.Year == train_year].reset_index()
    df_same_week_displaced_train = displaced_by_week(df, train_year)
    df_train_year['Load Last Week'] = df_same_week_displaced_train['Load']
    df_train_year['Load Difference'] = df_train_year['Load Last Week'] - df_train_year['Load']
    df_train_year['Temperature Difference'] = df_train_year['Temperature'] - df_same_week_displaced_train['Temperature']
    for test_year in range(2012, 2018):
            df_test_year = df[df.Year == test_year].reset_index()
            df_same_week_displaced_test = displaced_by_week(df, test_year)
            df_test_year['Load Last Week'] = df_same_week_displaced_test['Load']
            df_test_year['Load Difference'] = df_test_year['Load Last Week'] - df_test_year['Load']
            df_test_year['Temperature Difference'] = df_test_year['Temperature'] - df_same_week_displaced_test['Temperature']
            
            y_train = df_train_year['Load Difference']
            x_train = df_train_year[['Temperature Difference']]
            y_test = df_test_year['Load Difference']
            x_test = df_test_year[['Temperature Difference']]
            
            regressor = LinearRegression()
            result = regressor.fit(x_train, y_train)
            y_pred = regressor.predict(x_test)
            
            predicted_load = df_test_year['Load Last Week'] - y_pred
            actual_load = df_test_year['Load']
            metrics_df.loc[len(metrics_df)]=[train_year,test_year,regressor.coef_[0], regressor.intercept_, mean_absolute_percentage_error(actual_load, predicted_load)]

# %%
metrics_df[metrics_df['Training Year'] == metrics_df['Test Year']-1].sort_values('MAPE', ascending=True)
# Out:
#     Training Year  Test Year  Temp Difference Coefficient  Intercept      MAPE
# 8          2013.0     2014.0                     3.260703  -0.071235  3.516490
# 1          2012.0     2013.0                     1.788295   1.367677  3.702301
# 15         2014.0     2015.0                     3.306731   0.284881  3.919310
# 22         2015.0     2016.0                     4.759270   0.222334  4.331205
# 29         2016.0     2017.0                     4.322845   0.976925  5.447513

# %%
metrics_df[metrics_df['Training Year'] == metrics_df['Test Year']-1].MAPE.mean()
# Out:
# 4.183363866621886

# %%
metrics_df_transpose = metrics_df[['Training Year', 'Test Year', 'MAPE']].copy()
metrics_df_transpose = metrics_df_transpose.pivot(index='Training Year', columns='Test Year')
metrics_df_transpose.to_csv('load_last_week_temperature_corrected_year_by_year.csv')

# %% [markdown]
# # SDLW Weather Corrected Model

# %%
metrics_df = pd.DataFrame(columns=['Training Year', 'Test Year','Temp-48 Difference Coefficient', 'Wind speed coefficient', 'SD*PSR', 'Humidity', 'Intercept', 'MAPE'])
for train_year in range(2012, 2018):
    df_train_year = df[df.Year == train_year].reset_index()
    df_same_week_displaced_train = displaced_by_week(df, train_year)
    df_train_year['Load Last Week'] = df_same_week_displaced_train['Load']
    df_train_year['Load Difference'] = df_train_year['Load Last Week'] - df_train_year['Load']
    df_train_year['Temp-48 Difference'] = df_train_year['Temperature-48hrs'] - df_same_week_displaced_train['Temperature-48hrs']
    df_train_year['Wind speed Difference'] = df_train_year['Wind speed'] - df_same_week_displaced_train['Wind speed']
    df_train_year['Sun duration*potential solar irradiance Difference'] = df_train_year['Sun duration*potential solar irradiance'] - df_same_week_displaced_train['Sun duration*potential solar irradiance']
    df_train_year['Humidity Difference'] = df_train_year['Humidity'] - df_same_week_displaced_train['Humidity']
    for test_year in range(2012, 2018):
            df_test_year = df[df.Year == test_year].reset_index()
            df_same_week_displaced_test = displaced_by_week(df, test_year)
            df_test_year['Load Last Week'] = df_same_week_displaced_test['Load']
            df_test_year['Load Difference'] = df_test_year['Load Last Week'] - df_test_year['Load']
            df_test_year['Temp-48 Difference'] = df_test_year['Temperature-48hrs'] - df_same_week_displaced_test['Temperature-48hrs']
            df_test_year['Wind speed Difference'] = df_test_year['Wind speed'] - df_same_week_displaced_test['Wind speed']
            df_test_year['Sun duration*potential solar irradiance Difference'] = df_test_year['Sun duration*potential solar irradiance'] - df_same_week_displaced_test['Sun duration*potential solar irradiance']
            df_test_year['Humidity Difference'] = df_test_year['Humidity'] - df_same_week_displaced_test['Humidity']

            y_train = df_train_year['Load Difference']
            x_train = df_train_year[['Temp-48 Difference', 'Wind speed Difference', 'Sun duration*potential solar irradiance Difference', 'Humidity Difference']]
            y_test = df_test_year['Load Difference']
            x_test = df_test_year[['Temp-48 Difference', 'Wind speed Difference', 'Sun duration*potential solar irradiance Difference', 'Humidity Difference']]
            
            regressor = LinearRegression()
            result = regressor.fit(x_train, y_train)
            y_pred = regressor.predict(x_test)
            predicted_load = df_test_year['Load Last Week'] - y_pred
            actual_load = df_test_year['Load']
            metrics_df.loc[len(metrics_df)]=[train_year,test_year,regressor.coef_[0], regressor.coef_[1], regressor.coef_[2],  regressor.coef_[3], regressor.intercept_, mean_absolute_percentage_error(actual_load, predicted_load)]

# %%
metrics_df[metrics_df['Training Year'] == metrics_df['Test Year']-1].sort_values('MAPE', ascending=True)
# Out:
#     Training Year  Test Year  Temp-48 Difference Coefficient  \
# 8          2013.0     2014.0                        2.364357
# 1          2012.0     2013.0                        2.645796
# 15         2014.0     2015.0                        1.756487
# 22         2015.0     2016.0                        2.881873
# 29         2016.0     2017.0                        3.038653
#
#     Wind speed coefficient     SD*PSR  Humidity  Intercept      MAPE
# 8                -1.738904  32.543965 -0.766091  -0.099630  3.478995
# 1                -0.522038   9.123518 -0.672150   1.387950  3.579098
# 15               -0.079969  52.273976 -0.686200   0.257932  3.762766
# 22               -0.972294  96.931853 -1.048901   0.426211  4.124503
# 29                2.158660  96.361869 -1.422165   0.952083  5.079788

# %%
metrics_df[metrics_df['Training Year'] == metrics_df['Test Year']-1].MAPE.mean()
# Out:
# 4.005029951518447

# %%
metrics_df_transpose = metrics_df[['Training Year', 'Test Year', 'MAPE']].copy()
metrics_df_transpose = metrics_df_transpose.pivot(index='Training Year', columns='Test Year')
metrics_df_transpose.to_csv('load_last_week_wc_year_by_year.csv')
